# %% [markdown]
# # Python Statistics
#
# ## Data Upload

# %%
import numpy as np
import pandas as pd

import os as os
pd.__version__
# Out:
# '2.2.3'

# %%
data_path = './DataFiles/ames-housing-dataset/'
df = pd.read_csv(os.path.join(data_path,'AmesHousing.csv'),
                 engine='pyarrow', dtype_backend='pyarrow')

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.head(3)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL           141     31770   Pave
# 1      2  526350040           20        RH            80     11622   Pave
# 2      3  526351010           20        RL            81     14267   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0  <NA>       IR1          Lvl  ...         0    <NA>   <NA>         <NA>
# 1  <NA>       Reg          Lvl  ...         0    <NA>  MnPrv         <NA>
# 2  <NA>       IR1          Lvl  ...         0    <NA>   <NA>         Gar2
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       5    2010       WD           Normal     215000
# 1        0       6    2010       WD           Normal     105000
# 2    12500       6    2010       WD           Normal     172000
#
# [3 rows x 82 columns]

# %%
agg_df = df.describe()
agg_df
# Out:
#            Order               PID  MS SubClass  Lot Frontage      Lot Area  \
# count     2930.0            2930.0       2930.0        2440.0        2930.0
# mean      1465.5  714464496.988737    57.387372      69.22459  10147.921843
# std    845.96247   188730844.64939    42.638025     23.365335   7880.017759
# min          1.0       526301100.0         20.0          21.0        1300.0
# 25%       733.25       528477022.5         20.0          58.0       7440.25
# 50%       1465.5       535453620.0         50.0          68.0        9436.5
# 75%      2197.75       907181097.5         70.0          80.0      11555.25
# max       2930.0      1007100110.0        190.0         313.0      215245.0
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count        2930.0        2930.0       2930.0          2930.0        2907.0
# mean       6.094881       5.56314  1971.356314     1984.266553    101.896801
# ...

# %%
agg_df.iloc[0]['Order']
# Out:
# 2930.0

# %%
missing = {}

for col in agg_df.columns:
    if agg_df.iloc[0][col]<2930.0:
        missing[col] = [round(100*(2930.0-agg_df.iloc[0][col])/2930.0,2)]

pd.DataFrame(data=missing)
# Out:
#    Lot Frontage  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  \
# 0         16.72          0.78          0.03          0.03         0.03
#
#    Total Bsmt SF  Bsmt Full Bath  Bsmt Half Bath  Garage Yr Blt  Garage Cars  \
# 0           0.03            0.07            0.07           5.43         0.03
#
#    Garage Area
# 0         0.03

# %%
print(df.dtypes)
# Out:
# Order              int64[pyarrow]
# PID                int64[pyarrow]
# MS SubClass        int64[pyarrow]
# MS Zoning         string[pyarrow]
# Lot Frontage       int64[pyarrow]
#                        ...
# Mo Sold            int64[pyarrow]
# Yr Sold            int64[pyarrow]
# Sale Type         string[pyarrow]
# Sale Condition    string[pyarrow]
# SalePrice          int64[pyarrow]
# Length: 82, dtype: object

# %%
agg_df2 = (df
    .select_dtypes('string')
    .describe()
)
missing = {}

for col in agg_df2.columns:
    if agg_df2.iloc[0][col]<2930.0:
        missing[col] = [round(100*(2930.0-agg_df2.iloc[0][col])/2930.0,2)]

pd.DataFrame(data=missing)
# Out:
#    Alley  Mas Vnr Type  Bsmt Qual  Bsmt Cond  Bsmt Exposure  BsmtFin Type 1  \
# 0  93.24         60.58       2.73       2.73           2.83            2.73
#
#    BsmtFin Type 2  Electrical  Fireplace Qu  Garage Type  Garage Finish  \
# 0            2.76        0.03         48.53         5.36           5.43
#
#    Garage Qual  Garage Cond  Pool QC  Fence  Misc Feature
# 0         5.43         5.43    99.56  80.48         96.38

# %%
(df
 .select_dtypes('string')
 .memory_usage(deep=True)
 .sum()
)
# Out:
# np.int64(929599)

# %%
(df
 .select_dtypes('string')
 .astype('category')
 .memory_usage(deep=True)
 .sum()
)
# Out:
# np.int64(137945)

# %%
# missing

(df
 .isna()
 .mean()
 .mul(100)
 .pipe(lambda ser: ser[ser>0]))
# Out:
# Lot Frontage      16.723549
# Alley             93.242321
# Mas Vnr Type      60.580205
# Mas Vnr Area       0.784983
# Bsmt Qual          2.730375
# Bsmt Cond          2.730375
# Bsmt Exposure      2.832765
# BsmtFin Type 1     2.730375
# BsmtFin SF 1       0.034130
# BsmtFin Type 2     2.764505
# BsmtFin SF 2       0.034130
# Bsmt Unf SF        0.034130
# Total Bsmt SF      0.034130
# Electrical         0.034130
# Bsmt Full Bath     0.068259
# Bsmt Half Bath     0.068259
# Fireplace Qu      48.532423
# Garage Type        5.358362
# Garage Yr Blt      5.426621
# Garage Finish      5.426621
# Garage Cars        0.034130
# Garage Area        0.034130
# Garage Qual        5.426621
# Garage Cond        5.426621
# Pool QC           99.556314
# Fence             80.477816
# Misc Feature      96.382253
# dtype: float64

# %%
temp = (df
 .select_dtypes('string')
 .isna()
 .mean()
 .mul(100)
 .pipe(lambda ser: ser[ser>0])   
)
temp
# Out:
# Alley             93.242321
# Mas Vnr Type      60.580205
# Bsmt Qual          2.730375
# Bsmt Cond          2.730375
# Bsmt Exposure      2.832765
# BsmtFin Type 1     2.730375
# BsmtFin Type 2     2.764505
# Electrical         0.034130
# Fireplace Qu      48.532423
# Garage Type        5.358362
# Garage Finish      5.426621
# Garage Qual        5.426621
# Garage Cond        5.426621
# Pool QC           99.556314
# Fence             80.477816
# Misc Feature      96.382253
# dtype: float64

# %%
temp.index
# Out:
# Index(['Alley', 'Mas Vnr Type', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Electrical', 'Fireplace Qu',
#        'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Pool QC',
#        'Fence', 'Misc Feature'],
#       dtype='object')

# %%
temp = (df
 .select_dtypes('string')
 .eq('')
 .any()
)
temp
# Out:
# MS Zoning         False
# Street            False
# Alley             False
# Lot Shape         False
# Land Contour      False
# Utilities         False
# Lot Config        False
# Land Slope        False
# Neighborhood      False
# Condition 1       False
# Condition 2       False
# Bldg Type         False
# House Style       False
# Roof Style        False
# Roof Matl         False
# Exterior 1st      False
# Exterior 2nd      False
# Mas Vnr Type      False
# Exter Qual        False
# Exter Cond        False
# Foundation        False
# Bsmt Qual         False
# Bsmt Cond         False
# Bsmt Exposure     False
# BsmtFin Type 1    False
# BsmtFin Type 2    False
# Heating           False
# Heating QC        False
# Central Air       False
# Electrical        False
# Kitchen Qual      False
# Functional        False
# Fireplace Qu      False
# Garage Type       False
# Garage Finish     False
# Garage Qual       False
# Garage Cond       False
# Paved Drive       False
# ...

# %%
(df
 [~df.select_dtypes('string')
 .isna()
 .any(axis='columns')]
)
# Out:
# Empty DataFrame
# ...

# %%
(df
 .assign(
     **df.select_dtypes('string')
     .replace('', 'Not Applicable')
 ))
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL           141     31770   Pave
# 1         2  526350040           20        RH            80     11622   Pave
# 2         3  526351010           20        RL            81     14267   Pave
# 3         4  526353030           20        RL            93     11160   Pave
# 4         5  527105010           60        RL            74     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL            37      7937   Pave
# 2926   2927  923276100           20        RL          <NA>      8885   Pave
# 2927   2928  923400125           85        RL            62     10441   Pave
# 2928   2929  924100070           20        RL            77     10010   Pave
# 2929   2930  924151050           60        RL            74      9627   Pave
#
# ...
